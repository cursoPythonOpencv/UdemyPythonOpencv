# %% [markdown]
# # Template Matching - CAPTCHAS
#
# O objetivo desse programa é fazer o reconhecimento de caracteres de um CAPTCHA simples por calculo de template matching.
#
# **1. Etapa:**
#
# Fazer a conversão da imagem para espaço de cor HSV, aplicar os filtros, morfologia matemática, segmentação da imagem e cortar a imagem nos cinco caracteres presentes
#
# ![1-3.PNG](attachment:1-3.PNG)
#
# **2. Etapa:**
#
# Percorrer cada imagem cortada e calcular o template matching de cada.
#
# **3. Etapa:**
#
# Organizar o  vetor com os candidatos a solucao de acordo com  template matching calculado
#
# **4. Etapa:**
#
# Captchas solucao

# %%
#! python3

# Bibliotecas
import imutils
import cv2
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import random
import time
# %matplotlib inline


# Caminho
path = os.getcwd()

# Lendo todos os png existentes na pasta Repositorio captchas Cut
path_repositorio_captcha_cut = path + '\\Captcha_cut'
filelist_captcha_cut = [f for f in os.listdir(path_repositorio_captcha_cut) if f.endswith(".png")]

# Deletar os arquivos .png da pasta captcha cut
for f in filelist_captcha_cut:
    os.remove(os.path.join(path_repositorio_captcha_cut, f))


# Lendo todos os png existentes na pasta templates captchas 
path_repositorio_captcha = path + '\\templates'
filelist_captcha = [f for f in os.listdir(path_repositorio_captcha) if f.endswith(".png")]


# PEGAR O CAPTCHA
captcha_random = random.choice(filelist_captcha)
main_image = cv2.imread(path + f'\\templates\\{captcha_random}')

# %%
# Imagem no espaco HSV
hsv = cv2.cvtColor(main_image, cv2.COLOR_BGR2HSV)

# Limites superior e inferior
lim_inf = np.array([15, 0, 0])
lim_sup = np.array([103, 255, 255])

color_mask = cv2.inRange(hsv, lim_inf, lim_sup)

# Filtro Mediano
img_mediano = cv2.medianBlur(color_mask, 3)

# Filtro Bilateral
img_bilateral = cv2.bilateralFilter(img_mediano, 9, 75, 75)

# Img Erodida
elementoEstruturante = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
img_erode = cv2.erode(img_bilateral, elementoEstruturante, iterations=1)

# Threshold
img_th = cv2.adaptiveThreshold(img_erode, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 1)


# Dividir o Captcha em 5 e salvar
img_th1 = img_th[0:71, 0:79]
img_th2 = img_th[0:71, 80:159]
img_th3 = img_th[0:71, 160:238]
img_th4 = img_th[0:71, 239:317]
img_th5 = img_th[0:71, 318:]


cv2.imwrite(path + f'\\Captcha_cut\\captcha_pt_0.png', img_th1)
cv2.imwrite(path + f'\\Captcha_cut\\captcha_pt_1.png', img_th2)
cv2.imwrite(path + f'\\Captcha_cut\\captcha_pt_2.png', img_th3)
cv2.imwrite(path + f'\\Captcha_cut\\captcha_pt_3.png', img_th4)
cv2.imwrite(path + f'\\Captcha_cut\\captcha_pt_4.png', img_th5)
# Out:
# True

# %%
# Lendo todos os png existentes na pasta Repositorio captchas Cut
path_repositorio_captcha_cut = path + '\\Captcha_cut'
filelist_captcha_cut = [f for f in os.listdir(path_repositorio_captcha_cut) if f.endswith(".png")]


# Lendo todos os png existentes na pasta Repositorio dos templates
path_repositorio = path + '\\template_th_bk'
filelist = [f for f in os.listdir(path_repositorio) if f.endswith(".png")]

# %%
vetor_letras = []
max_valor_template = []

for j in range(len(filelist_captcha_cut)):

    img_captcha = cv2.imread(path + f'\\Captcha_cut\\{filelist_captcha_cut[j]}')
    

    for i in range(len(filelist)):

        # Ler a imagem template
        template = cv2.imread(path + f'\\template_th_bk\\{filelist[i]}')

        (height, width) = template.shape[:2]

        temp_found = None
        
        match = cv2.matchTemplate(img_captcha, template, cv2.TM_CCOEFF_NORMED)
        (_, val_max, _, loc_max) = cv2.minMaxLoc(match)

        # Matriz com os valores dos calculos de valores max
        max_valor_template.append([j,{filelist[i]:val_max}])


        print(f'O valor de correspondecia e: {val_max}')
print(max_valor_template)
# Out:
# O valor de correspondecia e: 0.21600982546806335
# O valor de correspondecia e: 0.5143327713012695
# O valor de correspondecia e: 0.5703341960906982
# O valor de correspondecia e: 0.41272345185279846
# O valor de correspondecia e: 0.5430391430854797
# O valor de correspondecia e: 0.6126569509506226
# O valor de correspondecia e: 0.45942366123199463
# O valor de correspondecia e: 0.602484941482544
# O valor de correspondecia e: 0.6186184287071228
# O valor de correspondecia e: 0.4366716146469116
# O valor de correspondecia e: 0.7553146481513977
# O valor de correspondecia e: 0.6357886791229248
# O valor de correspondecia e: 0.700433075428009
# O valor de correspondecia e: 0.6853249669075012
# O valor de correspondecia e: 0.5815364122390747
# O valor de correspondecia e: 0.3877427279949188
# O valor de correspondecia e: 0.7500013113021851
# O valor de correspondecia e: 0.7606976628303528
# O valor de correspondecia e: 0.06412407755851746
# O valor de correspondecia e: 0.5273641347885132
# O valor de correspondecia e: 0.5697808861732483
# O valor de correspondecia e: 0.3909858167171478
# O valor de correspondecia e: 0.7066988348960876
# O valor de correspondecia e: 0.750840425491333
# O valor de correspondecia e: 0.7592949271202087
# O valor de correspondecia e: 0.6035440564155579
# O valor de correspondecia e: 0.7430034279823303
# O valor de correspondecia e: 0.7087615132331848
# O valor de correspondecia e: 0.6718370914459229
# O valor de correspondecia e: 0.27662476897239685
# O valor de correspondecia e: 0.9941123127937317
# O valor de correspondecia e: 0.6315240263938904
# O valor de correspondecia e: 0.555280864238739
# O valor de correspondecia e: 0.4902811050415039
# O valor de correspondecia e: 0.4295341670513153
# O valor de correspondecia e: 0.417041152715683
# O valor de correspondecia e: 0.27733713388442993
# O valor de correspondecia e: 0.48786985874176025
# O valor de correspondecia e: 0.5569785833358765
# O valor de correspondecia e: 0.3652742803096771
# O valor de correspondecia e: 0.558855414390564
# O valor de correspondecia e: 0.625528872013092
# O valor de correspondecia e: 0.36779770255088806
# O valor de correspondecia e: 0.5940972566604614
# O valor de correspondecia e: 0.5734635591506958
# O valor de correspondecia e: 0.3948281705379486
# O valor de correspondecia e: 0.6976255178451538
# O valor de correspondecia e: 0.8542534708976746
# O valor de correspondecia e: 0.5095080733299255
# O valor de correspondecia e: 0.9007816314697266
# O valor de correspondecia e: 0.6130010485649109
# O valor de correspondecia e: 0.6149719953536987
# O valor de correspondecia e: 0.4247357249259949
# O valor de correspondecia e: 0.5154581665992737
# O valor de correspondecia e: 0.3193809986114502
# O valor de correspondecia e: 0.35723695158958435
# O valor de correspondecia e: 0.38875240087509155
# O valor de correspondecia e: 0.4501079022884369
# O valor de correspondecia e: 0.5415355563163757
# O valor de correspondecia e: 0.42880702018737793
# O valor de correspondecia e: 0.3055833578109741
# O valor de correspondecia e: 0.5139544010162354
# O valor de correspondecia e: 0.6413559913635254
# O valor de correspondecia e: 0.41047734022140503
# O valor de correspondecia e: 0.26393792033195496
# O valor de correspondecia e: 0.46091073751449585
# O valor de correspondecia e: 0.4216826558113098
# O valor de correspondecia e: 0.38250797986984253
# O valor de correspondecia e: 0.49865400791168213
# O valor de correspondecia e: 0.3785128593444824
# O valor de correspondecia e: 0.44371291995048523
# O valor de correspondecia e: 0.5371460914611816
# O valor de correspondecia e: 0.7689240574836731
# O valor de correspondecia e: 0.40677571296691895
# O valor de correspondecia e: 0.5576975345611572
# O valor de correspondecia e: 0.3132285177707672
# O valor de correspondecia e: 0.4939207434654236
# O valor de correspondecia e: 0.6376218795776367
# O valor de correspondecia e: 0.6595405340194702
# O valor de correspondecia e: 0.3716028034687042
# O valor de correspondecia e: 0.4350631535053253
# O valor de correspondecia e: 0.47606632113456726
# O valor de correspondecia e: 0.543984591960907
# O valor de correspondecia e: 0.45621582865715027
# O valor de correspondecia e: 0.5732366442680359
# O valor de correspondecia e: 0.3037489950656891
# O valor de correspondecia e: 0.5348712205886841
# O valor de correspondecia e: 0.544411301612854
# O valor de correspondecia e: 0.650184154510498
# O valor de correspondecia e: 0.6230186223983765
# O valor de correspondecia e: 0.45700719952583313
# O valor de correspondecia e: 0.520220160484314
# O valor de correspondecia e: 0.581611156463623
# O valor de correspondecia e: 0.49419552087783813
# O valor de correspondecia e: 0.46427831053733826
# O valor de correspondecia e: 0.5809760689735413
# O valor de correspondecia e: 0.6044571995735168
# O valor de correspondecia e: 0.35647934675216675
# O valor de correspondecia e: 0.4270938038825989
# O valor de correspondecia e: 0.5535202026367188
# O valor de correspondecia e: 0.3664582073688507
# O valor de correspondecia e: 0.6602615714073181
# O valor de correspondecia e: 0.5925151109695435
# O valor de correspondecia e: 0.5813115835189819
# O valor de correspondecia e: 0.5491971969604492
# O valor de correspondecia e: 0.603534996509552
# O valor de correspondecia e: 0.6260786056518555
# O valor de correspondecia e: 0.5281640887260437
# O valor de correspondecia e: 0.31862911581993103
# O valor de correspondecia e: 0.5516390800476074
# O valor de correspondecia e: 0.418587863445282
# O valor de correspondecia e: 0.7851101160049438
# O valor de correspondecia e: 0.5492761135101318
# O valor de correspondecia e: 0.3588198125362396
0.2692814767360687}], [1, {'Z.png': 0.4397386610507965}], [2, {'1.png': 0.27243170142173767}], [2, {'2.png': 0.5555965900421143}], [2, {'3.png': 0.6426106095314026}], [2, {'4.png': 0.38744640350341797}], [2, {'5.png': 0.5812795162200928}], [2, {'6.png': 0.654305100440979}], [2, {'7.png': 0.4396175146102905}], [2, {'8.png': 0.6384041905403137}], [2, {'9.png': 0.6581131815910339}], [2, {'A.png': 0.45422330498695374}], [2, {'B.png': 0.759915828704834}], [2, {'C-Dilha.png': 0.710913896560669}], [2, {'C.png': 0.7714580297470093}], [2, {'D.png': 0.7953658699989319}], [2, {'E.png': 0.6131253242492676}], [2, {'F.png': 0.4338919520378113}], [2, {'G.png': 0.8839254379272461}], [2, {'H.png': 0.6444022059440613}], [2, {'I.png': 0.22016938030719757}], [2, {'J.png': 0.4951346218585968}], [2, {'K.png': 0.5012239217758179}], [2, {'L.png': 0.423049658536911}], [2, {'M.png': 0.6473526954650879}], [2, {'N.png': 0.6443368792533875}], [2, {'O.png': 0.9035861492156982}], [2, {'P.png': 0.6138417720794678}], [2, {'Q.png': 0.8537755608558655}], [2, {'R.png': 0.683901846408844}], [2, {'S.png': 0.7438492774963379}], [2, {'T.png': 0.29886963963508606}], [2, {'U.png': 0.779624879360199}], [2, {'V.png': 0.482222318649292}], [2, {'W.png': 0.5788555145263672}], [2, {'X.png': 0.4018953740596771}], [2, {'Y.png': 0.3113647699356079}], [2, {'Z.png': 0.47088944911956787}], [3, {'1.png': 0.5998464822769165}], [3, {'2.png': 0.7025892734527588}], [3, {'3.png': 0.6 ...

# %%
# Organizando o vetor com os candidatos a solucao de acordo com a potuacao do vetor max_valor_template
mat = pd.DataFrame(max_valor_template)

list_mat = list(mat.groupby([0]))
#print(list_mat)

campeoes=[] # Matriz com os templates com melhor valor_max calculado

for i in range(len(list_mat)):
    a = list_mat[i][1]
    pontos = [list(valor.values()) for valor in a[1]]
    pontuacao = [ponto[0] for ponto in pontos]
    campea = np.flip(np.argsort(pontuacao))

    campeoes.append(campea[0])

print(campeoes)
# Out:
# [30, 11, 24, 6, 32]

# %%
# Vetor dos captchas solucao
letras_captchas = []
for j in range(len(campeoes)):
    letras_captchas.append(filelist[campeoes[j]].split('.')[0])

letras_captchas_total = pd.Series(letras_captchas)

letras_captchas_total = letras_captchas_total.str.replace('C-Dilha', 'Ç')

letras_captchas_total = letras_captchas_total.tolist()
print(letras_captchas_total)
print(captcha_random)
# Out:
# ['U', 'Ç', 'O', '7', 'W']
# frame940.png

# %%
plt.subplot(3,2,1), plt.imshow(main_image)
plt.subplot(3,2,2), plt.imshow(color_mask)
plt.subplot(3,2,3), plt.imshow(img_bilateral, cmap='gray')
plt.subplot(3,2,4), plt.imshow(img_erode, cmap='gray')
plt.subplot(3,2,5), plt.imshow(img_th, cmap='gray')
plt.show()
